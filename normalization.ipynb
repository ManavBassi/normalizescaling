# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ads=pd.read_csv('/content/Social_Network_Ads.csv')
ads.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
new=ads[['Age','EstimatedSalary', 'Purchased']]

# %%
from sklearn.model_selection import  train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(new.drop('Purchased',axis=1),new['Purchased'],test_size=0.3,random_state=0)

# %%
x_train.shape,x_test.shape
# Out:
# ((280, 2), (120, 2))

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(x_train)
x_train_scaled=scaler.transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
np.round(x_train.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.9          69807.1
# std     10.2          34641.2
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          70500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
x_train_scaled=pd.DataFrame(x_train_scaled,columns=x_train.columns)
x_test_scaled=pd.DataFrame(x_test_scaled,columns=x_test.columns)

# %%
np.round(x_train_scaled.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.5              0.4
# std      0.2              0.3
# min      0.0              0.0
# 25%      0.3              0.2
# 50%      0.5              0.4
# 75%      0.7              0.5
# max      1.0              1.0

# %% [markdown]
# # effect of scaling

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))
ax1.scatter(x_train['Age'],x_train['EstimatedSalary'])
ax1.set_title("before scaling")
ax2.scatter(x_train_scaled['Age'],x_train_scaled['EstimatedSalary'],color='r')
ax2.set_title("after scaling")
# Out:
# Text(0.5, 1.0, 'after scaling')

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))
sns.kdeplot(x_train['Age'],ax=ax1)
sns.kdeplot(x_train['EstimatedSalary'],ax=ax1)
ax1.set_title("before scaling")
sns.kdeplot(x_train_scaled['Age'],ax=ax2)
sns.kdeplot(x_train_scaled['EstimatedSalary'],ax=ax2)
ax2.set_title("after scaling")
# Out:
# Text(0.5, 1.0, 'after scaling')

# %% [markdown]
# # max absolute scaler

# %%
from sklearn.preprocessing import MaxAbsScaler

scaler1 = MaxAbsScaler()
x_train_scaled1 = scaler1.fit_transform(x_train)
x_test_scaled1=scaler1.transform(x_test)

# %%
np.round(x_train.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.9          69807.1
# std     10.2          34641.2
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          70500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
x_train_scaled1=pd.DataFrame(x_train_scaled1,columns=x_train.columns)
x_test_scaled1=pd.DataFrame(x_test_scaled1,columns=x_test.columns)

# %%
np.round(x_train_scaled1.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.6              0.5
# std      0.2              0.2
# min      0.3              0.1
# 25%      0.5              0.3
# 50%      0.6              0.5
# 75%      0.8              0.6
# max      1.0              1.0

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))
sns.kdeplot(x_train['Age'],ax=ax1)
sns.kdeplot(x_train['EstimatedSalary'],ax=ax1)
ax1.set_title("before scaling")
sns.kdeplot(x_train_scaled1['Age'],ax=ax2)
sns.kdeplot(x_train_scaled1['EstimatedSalary'],ax=ax2)
ax2.set_title("after scaling")
# Out:
# Text(0.5, 1.0, 'after scaling')

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))
ax1.scatter(x_train['Age'],x_train['EstimatedSalary'])
ax1.set_title("before scaling")
ax2.scatter(x_train_scaled1['Age'],x_train_scaled1['EstimatedSalary'],color='r')
ax2.set_title("after scaling")
# Out:
# Text(0.5, 1.0, 'after scaling')

# %% [markdown]
# # robust scaler

# %%
from sklearn.preprocessing import RobustScaler

scaler2 = RobustScaler()
x_train_scaled2 = scaler2.fit_transform(x_train)
x_test_scaled2=scaler2.transform(x_test)

# %%
np.round(x_train.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.9          69807.1
# std     10.2          34641.2
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          70500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
x_train_scaled2=pd.DataFrame(x_train_scaled2,columns=x_train.columns)
x_test_scaled2=pd.DataFrame(x_test_scaled2,columns=x_test.columns)

# %%
np.round(x_train_scaled2.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.1             -0.0
# std      0.6              0.8
# min     -1.2             -1.2
# 25%     -0.4             -0.6
# 50%      0.0              0.0
# 75%      0.6              0.4
# max      1.4              1.8

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))
ax1.scatter(x_train['Age'],x_train['EstimatedSalary'])
ax1.set_title("before scaling")
ax2.scatter(x_train_scaled2['Age'],x_train_scaled2['EstimatedSalary'],color='r')
ax2.set_title("after scaling")
# Out:
# Text(0.5, 1.0, 'after scaling')

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))
sns.kdeplot(x_train['Age'],ax=ax1)
sns.kdeplot(x_train['EstimatedSalary'],ax=ax1)
ax1.set_title("before scaling")
sns.kdeplot(x_train_scaled2['Age'],ax=ax2)
sns.kdeplot(x_train_scaled2['EstimatedSalary'],ax=ax2)
ax2.set_title("after scaling")
# Out:
# Text(0.5, 1.0, 'after scaling')
